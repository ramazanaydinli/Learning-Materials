# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 905us/sample - loss: 250.1569 - y1_output_loss: 121.7115 - y2_output_loss: 126.1608 - y1_output_root_mean_squared_error: 11.0840 - y2_output_root_mean_squared_error: 11.2828 - val_loss: 50.1672 - val_y1_output_loss: 19.2507 - val_y2_output_loss: 29.7801 - val_y1_output_root_mean_squared_error: 4.4125 - val_y2_output_root_mean_squared_error: 5.5405
# Epoch 2/500
# 614/614 [==============================] - 0s 144us/sample - loss: 29.0430 - y1_output_loss: 12.1210 - y2_output_loss: 17.1350 - y1_output_root_mean_squared_error: 3.4573 - y2_output_root_mean_squared_error: 4.1340 - val_loss: 29.8171 - val_y1_output_loss: 13.9458 - val_y2_output_loss: 15.7755 - val_y1_output_root_mean_squared_error: 3.7380 - val_y2_output_root_mean_squared_error: 3.9805
# Epoch 3/500
# 614/614 [==============================] - 0s 137us/sample - loss: 28.4024 - y1_output_loss: 10.5266 - y2_output_loss: 18.0225 - y1_output_root_mean_squared_error: 3.2302 - y2_output_root_mean_squared_error: 4.2389 - val_loss: 98.7262 - val_y1_output_loss: 30.3297 - val_y2_output_loss: 72.5074 - val_y1_output_root_mean_squared_error: 5.4293 - val_y2_output_root_mean_squared_error: 8.3216
# Epoch 4/500
# 614/614 [==============================] - 0s 141us/sample - loss: 25.7466 - y1_output_loss: 9.7037 - y2_output_loss: 16.0040 - y1_output_root_mean_squared_error: 3.1228 - y2_output_root_mean_squared_error: 3.9994 - val_loss: 33.8329 - val_y1_output_loss: 13.1693 - val_y2_output_loss: 21.6129 - val_y1_output_root_mean_squared_error: 3.6070 - val_y2_output_root_mean_squared_error: 4.5632
# Epoch 5/500
# 614/614 [==============================] - 0s 135us/sample - loss: 19.9516 - y1_output_loss: 8.1719 - y2_output_loss: 11.6535 - y1_output_root_mean_squared_error: 2.8687 - y2_output_root_mean_squared_error: 3.4238 - val_loss: 27.5516 - val_y1_output_loss: 12.4009 - val_y2_output_loss: 16.0808 - val_y1_output_root_mean_squared_error: 3.4745 - val_y2_output_root_mean_squared_error: 3.9344
# Epoch 6/500
# 614/614 [==============================] - 0s 135us/sample - loss: 21.0491 - y1_output_loss: 8.2533 - y2_output_loss: 12.6798 - y1_output_root_mean_squared_error: 2.8851 - y2_output_root_mean_squared_error: 3.5672 - val_loss: 26.7229 - val_y1_output_loss: 11.0640 - val_y2_output_loss: 16.7717 - val_y1_output_root_mean_squared_error: 3.2712 - val_y2_output_root_mean_squared_error: 4.0028
# Epoch 7/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.1306 - y1_output_loss: 7.8974 - y2_output_loss: 13.1093 - y1_output_root_mean_squared_error: 2.8169 - y2_output_root_mean_squared_error: 3.6326 - val_loss: 29.5745 - val_y1_output_loss: 10.1706 - val_y2_output_loss: 18.9441 - val_y1_output_root_mean_squared_error: 3.1877 - val_y2_output_root_mean_squared_error: 4.4060
# Epoch 8/500
# 614/614 [==============================] - 0s 140us/sample - loss: 21.5364 - y1_output_loss: 7.9182 - y2_output_loss: 13.6581 - y1_output_root_mean_squared_error: 2.7955 - y2_output_root_mean_squared_error: 3.7043 - val_loss: 26.9493 - val_y1_output_loss: 12.5970 - val_y2_output_loss: 15.0068 - val_y1_output_root_mean_squared_error: 3.5227 - val_y2_output_root_mean_squared_error: 3.8131
# Epoch 9/500
# 614/614 [==============================] - 0s 133us/sample - loss: 19.1268 - y1_output_loss: 7.8127 - y2_output_loss: 11.1837 - y1_output_root_mean_squared_error: 2.8062 - y2_output_root_mean_squared_error: 3.3544 - val_loss: 26.2386 - val_y1_output_loss: 11.2541 - val_y2_output_loss: 16.0808 - val_y1_output_root_mean_squared_error: 3.3019 - val_y2_output_root_mean_squared_error: 3.9161
# Epoch 10/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.7297 - y1_output_loss: 7.2324 - y2_output_loss: 10.5009 - y1_output_root_mean_squared_error: 2.6979 - y2_output_root_mean_squared_error: 3.2328 - val_loss: 29.3144 - val_y1_output_loss: 10.3779 - val_y2_output_loss: 20.5268 - val_y1_output_root_mean_squared_error: 3.1614 - val_y2_output_root_mean_squared_error: 4.3954
# Epoch 11/500
# 614/614 [==============================] - 0s 139us/sample - loss: 18.6808 - y1_output_loss: 7.2459 - y2_output_loss: 11.7153 - y1_output_root_mean_squared_error: 2.6852 - y2_output_root_mean_squared_error: 3.3868 - val_loss: 38.1209 - val_y1_output_loss: 10.7244 - val_y2_output_loss: 29.0494 - val_y1_output_root_mean_squared_error: 3.2309 - val_y2_output_root_mean_squared_error: 5.2614
# Epoch 12/500
# 614/614 [==============================] - 0s 139us/sample - loss: 19.2871 - y1_output_loss: 7.2219 - y2_output_loss: 11.9042 - y1_output_root_mean_squared_error: 2.6984 - y2_output_root_mean_squared_error: 3.4649 - val_loss: 20.6013 - val_y1_output_loss: 8.7628 - val_y2_output_loss: 12.4220 - val_y1_output_root_mean_squared_error: 2.9157 - val_y2_output_root_mean_squared_error: 3.4785
# Epoch 13/500
# 614/614 [==============================] - 0s 136us/sample - loss: 17.8097 - y1_output_loss: 6.7921 - y2_output_loss: 10.9700 - y1_output_root_mean_squared_error: 2.5972 - y2_output_root_mean_squared_error: 3.3263 - val_loss: 22.2711 - val_y1_output_loss: 8.6620 - val_y2_output_loss: 13.8806 - val_y1_output_root_mean_squared_error: 2.9018 - val_y2_output_root_mean_squared_error: 3.7216
# Epoch 14/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.9183 - y1_output_loss: 6.3754 - y2_output_loss: 10.4565 - y1_output_root_mean_squared_error: 2.5326 - y2_output_root_mean_squared_error: 3.2410 - val_loss: 21.0875 - val_y1_output_loss: 8.7894 - val_y2_output_loss: 13.0306 - val_y1_output_root_mean_squared_error: 2.9224 - val_y2_output_root_mean_squared_error: 3.5422
# Epoch 15/500
# 614/614 [==============================] - 0s 136us/sample - loss: 16.8206 - y1_output_loss: 6.4625 - y2_output_loss: 10.4335 - y1_output_root_mean_squared_error: 2.5460 - y2_output_root_mean_squared_error: 3.2153 - val_loss: 37.3133 - val_y1_output_loss: 10.5233 - val_y2_output_loss: 28.9403 - val_y1_output_root_mean_squared_error: 3.1836 - val_y2_output_root_mean_squared_error: 5.2133
# Epoch 16/500
# 614/614 [==============================] - 0s 138us/sample - loss: 15.0145 - y1_output_loss: 6.0874 - y2_output_loss: 9.2615 - y1_output_root_mean_squared_error: 2.4491 - y2_output_root_mean_squared_error: 3.0027 - val_loss: 37.4860 - val_y1_output_loss: 10.3241 - val_y2_output_loss: 28.8884 - val_y1_output_root_mean_squared_error: 3.1681 - val_y2_output_root_mean_squared_error: 5.2392
# Epoch 17/500
# 614/614 [==============================] - 0s 140us/sample - loss: 15.6849 - y1_output_loss: 6.0519 - y2_output_loss: 9.7994 - y1_output_root_mean_squared_error: 2.4373 - y2_output_root_mean_squared_error: 3.1216 - val_loss: 68.1340 - val_y1_output_loss: 21.8500 - val_y2_output_loss: 45.7473 - val_y1_output_root_mean_squared_error: 4.6583 - val_y2_output_root_mean_squared_error: 6.8143
# Epoch 18/500
# 614/614 [==============================] - 0s 135us/sample - loss: 19.1559 - y1_output_loss: 6.8251 - y2_output_loss: 12.9096 - y1_output_root_mean_squared_error: 2.5897 - y2_output_root_mean_squared_error: 3.5284 - val_loss: 116.5999 - val_y1_output_loss: 28.6087 - val_y2_output_loss: 88.2689 - val_y1_output_root_mean_squared_error: 5.3007 - val_y2_output_root_mean_squared_error: 9.4076
# Epoch 19/500
# 614/614 [==============================] - 0s 141us/sample - loss: 14.8641 - y1_output_loss: 5.7936 - y2_output_loss: 9.2154 - y1_output_root_mean_squared_error: 2.3957 - y2_output_root_mean_squared_error: 3.0207 - val_loss: 36.0743 - val_y1_output_loss: 10.8272 - val_y2_output_loss: 24.9119 - val_y1_output_root_mean_squared_error: 3.2681 - val_y2_output_root_mean_squared_error: 5.0392
# Epoch 20/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.2295 - y1_output_loss: 5.7360 - y2_output_loss: 10.3759 - y1_output_root_mean_squared_error: 2.4039 - y2_output_root_mean_squared_error: 3.2327 - val_loss: 15.5691 - val_y1_output_loss: 6.1765 - val_y2_output_loss: 9.6450 - val_y1_output_root_mean_squared_error: 2.4364 - val_y2_output_root_mean_squared_error: 3.1038
# Epoch 21/500
# 614/614 [==============================] - 0s 133us/sample - loss: 20.2972 - y1_output_loss: 6.9325 - y2_output_loss: 13.4284 - y1_output_root_mean_squared_error: 2.6312 - y2_output_root_mean_squared_error: 3.6570 - val_loss: 23.4204 - val_y1_output_loss: 9.6839 - val_y2_output_loss: 13.7142 - val_y1_output_root_mean_squared_error: 3.0887 - val_y2_output_root_mean_squared_error: 3.7256
# Epoch 22/500
# 614/614 [==============================] - 0s 138us/sample - loss: 14.0291 - y1_output_loss: 5.3931 - y2_output_loss: 9.2173 - y1_output_root_mean_squared_error: 2.3147 - y2_output_root_mean_squared_error: 2.9447 - val_loss: 79.6729 - val_y1_output_loss: 12.6927 - val_y2_output_loss: 71.6654 - val_y1_output_root_mean_squared_error: 3.4395 - val_y2_output_root_mean_squared_error: 8.2367
# Epoch 23/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.7248 - y1_output_loss: 4.9134 - y2_output_loss: 7.7427 - y1_output_root_mean_squared_error: 2.2194 - y2_output_root_mean_squared_error: 2.7926 - val_loss: 15.3966 - val_y1_output_loss: 7.2255 - val_y2_output_loss: 8.5959 - val_y1_output_root_mean_squared_error: 2.6468 - val_y2_output_root_mean_squared_error: 2.8968
# Epoch 24/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.8275 - y1_output_loss: 4.8999 - y2_output_loss: 7.8779 - y1_output_root_mean_squared_error: 2.2178 - y2_output_root_mean_squared_error: 2.8123 - val_loss: 14.6960 - val_y1_output_loss: 5.7572 - val_y2_output_loss: 9.5025 - val_y1_output_root_mean_squared_error: 2.3580 - val_y2_output_root_mean_squared_error: 3.0226
# Epoch 25/500
# 614/614 [==============================] - 0s 142us/sample - loss: 11.7775 - y1_output_loss: 4.5296 - y2_output_loss: 7.1944 - y1_output_root_mean_squared_error: 2.1295 - y2_output_root_mean_squared_error: 2.6912 - val_loss: 16.1452 - val_y1_output_loss: 5.7581 - val_y2_output_loss: 10.5484 - val_y1_output_root_mean_squared_error: 2.3416 - val_y2_output_root_mean_squared_error: 3.2653
# Epoch 26/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.4437 - y1_output_loss: 4.4648 - y2_output_loss: 6.8822 - y1_output_root_mean_squared_error: 2.1227 - y2_output_root_mean_squared_error: 2.6340 - val_loss: 21.5978 - val_y1_output_loss: 6.7941 - val_y2_output_loss: 14.7489 - val_y1_output_root_mean_squared_error: 2.5742 - val_y2_output_root_mean_squared_error: 3.8693
# Epoch 27/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.6136 - y1_output_loss: 4.4464 - y2_output_loss: 8.1770 - y1_output_root_mean_squared_error: 2.1146 - y2_output_root_mean_squared_error: 2.8534 - val_loss: 22.7731 - val_y1_output_loss: 7.0629 - val_y2_output_loss: 17.1525 - val_y1_output_root_mean_squared_error: 2.5878 - val_y2_output_root_mean_squared_error: 4.0095
# Epoch 28/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.8483 - y1_output_loss: 4.4854 - y2_output_loss: 7.4614 - y1_output_root_mean_squared_error: 2.0897 - y2_output_root_mean_squared_error: 2.7352 - val_loss: 28.2242 - val_y1_output_loss: 12.9131 - val_y2_output_loss: 16.6948 - val_y1_output_root_mean_squared_error: 3.5241 - val_y2_output_root_mean_squared_error: 3.9755
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.4519 - y1_output_loss: 4.2964 - y2_output_loss: 7.2370 - y1_output_root_mean_squared_error: 2.0772 - y2_output_root_mean_squared_error: 2.6716 - val_loss: 13.1773 - val_y1_output_loss: 4.8658 - val_y2_output_loss: 8.8306 - val_y1_output_root_mean_squared_error: 2.1646 - val_y2_output_root_mean_squared_error: 2.9140
# Epoch 30/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.8372 - y1_output_loss: 3.6680 - y2_output_loss: 6.2919 - y1_output_root_mean_squared_error: 1.9049 - y2_output_root_mean_squared_error: 2.4917 - val_loss: 19.7146 - val_y1_output_loss: 6.5690 - val_y2_output_loss: 12.7749 - val_y1_output_root_mean_squared_error: 2.5554 - val_y2_output_root_mean_squared_error: 3.6311
# Epoch 31/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.2753 - y1_output_loss: 3.1799 - y2_output_loss: 5.0168 - y1_output_root_mean_squared_error: 1.7916 - y2_output_root_mean_squared_error: 2.2506 - val_loss: 11.5415 - val_y1_output_loss: 5.1088 - val_y2_output_loss: 6.8147 - val_y1_output_root_mean_squared_error: 2.2181 - val_y2_output_root_mean_squared_error: 2.5732
# Epoch 32/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.9837 - y1_output_loss: 3.2159 - y2_output_loss: 5.7222 - y1_output_root_mean_squared_error: 1.7977 - y2_output_root_mean_squared_error: 2.3983 - val_loss: 11.0779 - val_y1_output_loss: 4.0855 - val_y2_output_loss: 7.0931 - val_y1_output_root_mean_squared_error: 1.9872 - val_y2_output_root_mean_squared_error: 2.6700
# Epoch 33/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.4204 - y1_output_loss: 3.0746 - y2_output_loss: 5.3342 - y1_output_root_mean_squared_error: 1.7516 - y2_output_root_mean_squared_error: 2.3135 - val_loss: 14.5952 - val_y1_output_loss: 6.2480 - val_y2_output_loss: 8.9629 - val_y1_output_root_mean_squared_error: 2.4533 - val_y2_output_root_mean_squared_error: 2.9285
# Epoch 34/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.0020 - y1_output_loss: 3.2968 - y2_output_loss: 5.7654 - y1_output_root_mean_squared_error: 1.8070 - y2_output_root_mean_squared_error: 2.3951 - val_loss: 14.2894 - val_y1_output_loss: 5.2222 - val_y2_output_loss: 9.1194 - val_y1_output_root_mean_squared_error: 2.2464 - val_y2_output_root_mean_squared_error: 3.0403
# Epoch 35/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.0289 - y1_output_loss: 3.0121 - y2_output_loss: 5.2187 - y1_output_root_mean_squared_error: 1.7310 - y2_output_root_mean_squared_error: 2.2433 - val_loss: 40.1135 - val_y1_output_loss: 9.0587 - val_y2_output_loss: 32.7015 - val_y1_output_root_mean_squared_error: 2.9636 - val_y2_output_root_mean_squared_error: 5.5974
# Epoch 36/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.4432 - y1_output_loss: 3.2111 - y2_output_loss: 6.3487 - y1_output_root_mean_squared_error: 1.7881 - y2_output_root_mean_squared_error: 2.4992 - val_loss: 9.0172 - val_y1_output_loss: 3.4924 - val_y2_output_loss: 5.7521 - val_y1_output_root_mean_squared_error: 1.8329 - val_y2_output_root_mean_squared_error: 2.3786
# Epoch 37/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.8258 - y1_output_loss: 2.7680 - y2_output_loss: 5.0715 - y1_output_root_mean_squared_error: 1.6693 - y2_output_root_mean_squared_error: 2.2449 - val_loss: 14.7010 - val_y1_output_loss: 4.7236 - val_y2_output_loss: 10.3989 - val_y1_output_root_mean_squared_error: 2.1618 - val_y2_output_root_mean_squared_error: 3.1667
# Epoch 38/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.4181 - y1_output_loss: 2.9213 - y2_output_loss: 5.4271 - y1_output_root_mean_squared_error: 1.7168 - y2_output_root_mean_squared_error: 2.3389 - val_loss: 8.8058 - val_y1_output_loss: 3.3921 - val_y2_output_loss: 5.6392 - val_y1_output_root_mean_squared_error: 1.8038 - val_y2_output_root_mean_squared_error: 2.3563
# Epoch 39/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.3716 - y1_output_loss: 3.4647 - y2_output_loss: 6.8300 - y1_output_root_mean_squared_error: 1.8679 - y2_output_root_mean_squared_error: 2.6235 - val_loss: 8.7219 - val_y1_output_loss: 3.2313 - val_y2_output_loss: 5.4957 - val_y1_output_root_mean_squared_error: 1.7806 - val_y2_output_root_mean_squared_error: 2.3561
# Epoch 40/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.3229 - y1_output_loss: 2.4047 - y2_output_loss: 4.8845 - y1_output_root_mean_squared_error: 1.5476 - y2_output_root_mean_squared_error: 2.2199 - val_loss: 10.7656 - val_y1_output_loss: 4.4614 - val_y2_output_loss: 6.2784 - val_y1_output_root_mean_squared_error: 2.0999 - val_y2_output_root_mean_squared_error: 2.5211
# Epoch 41/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.1671 - y1_output_loss: 2.5344 - y2_output_loss: 5.6419 - y1_output_root_mean_squared_error: 1.5919 - y2_output_root_mean_squared_error: 2.3734 - val_loss: 17.9453 - val_y1_output_loss: 4.2184 - val_y2_output_loss: 13.4301 - val_y1_output_root_mean_squared_error: 2.0319 - val_y2_output_root_mean_squared_error: 3.7171
# Epoch 42/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.9699 - y1_output_loss: 2.9383 - y2_output_loss: 6.1747 - y1_output_root_mean_squared_error: 1.7000 - y2_output_root_mean_squared_error: 2.4658 - val_loss: 17.9172 - val_y1_output_loss: 5.0504 - val_y2_output_loss: 12.6089 - val_y1_output_root_mean_squared_error: 2.2289 - val_y2_output_root_mean_squared_error: 3.5985
# Epoch 43/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.8798 - y1_output_loss: 3.0880 - y2_output_loss: 6.7962 - y1_output_root_mean_squared_error: 1.7520 - y2_output_root_mean_squared_error: 2.6097 - val_loss: 25.1096 - val_y1_output_loss: 10.1350 - val_y2_output_loss: 15.7385 - val_y1_output_root_mean_squared_error: 3.1585 - val_y2_output_root_mean_squared_error: 3.8902
# Epoch 44/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.3931 - y1_output_loss: 2.4967 - y2_output_loss: 4.9619 - y1_output_root_mean_squared_error: 1.5793 - y2_output_root_mean_squared_error: 2.2133 - val_loss: 29.2894 - val_y1_output_loss: 7.2746 - val_y2_output_loss: 23.2426 - val_y1_output_root_mean_squared_error: 2.6660 - val_y2_output_root_mean_squared_error: 4.7098
# Epoch 45/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.6992 - y1_output_loss: 2.8055 - y2_output_loss: 5.8232 - y1_output_root_mean_squared_error: 1.6805 - y2_output_root_mean_squared_error: 2.4239 - val_loss: 10.1353 - val_y1_output_loss: 3.1804 - val_y2_output_loss: 7.4383 - val_y1_output_root_mean_squared_error: 1.7448 - val_y2_output_root_mean_squared_error: 2.6629
# Epoch 46/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.5953 - y1_output_loss: 2.1237 - y2_output_loss: 4.5069 - y1_output_root_mean_squared_error: 1.4555 - y2_output_root_mean_squared_error: 2.1158 - val_loss: 10.9903 - val_y1_output_loss: 4.5231 - val_y2_output_loss: 6.5748 - val_y1_output_root_mean_squared_error: 2.0900 - val_y2_output_root_mean_squared_error: 2.5733
# Epoch 47/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.1210 - y1_output_loss: 2.4015 - y2_output_loss: 4.7098 - y1_output_root_mean_squared_error: 1.5532 - y2_output_root_mean_squared_error: 2.1699 - val_loss: 11.7968 - val_y1_output_loss: 4.6727 - val_y2_output_loss: 7.6858 - val_y1_output_root_mean_squared_error: 2.1071 - val_y2_output_root_mean_squared_error: 2.7124
# Epoch 48/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.1850 - y1_output_loss: 1.9612 - y2_output_loss: 4.1946 - y1_output_root_mean_squared_error: 1.4067 - y2_output_root_mean_squared_error: 2.0509 - val_loss: 9.3251 - val_y1_output_loss: 3.5673 - val_y2_output_loss: 5.7362 - val_y1_output_root_mean_squared_error: 1.8641 - val_y2_output_root_mean_squared_error: 2.4187
# Epoch 49/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.1771 - y1_output_loss: 2.6688 - y2_output_loss: 5.4652 - y1_output_root_mean_squared_error: 1.6382 - y2_output_root_mean_squared_error: 2.3438 - val_loss: 7.7629 - val_y1_output_loss: 2.6411 - val_y2_output_loss: 5.1218 - val_y1_output_root_mean_squared_error: 1.6092 - val_y2_output_root_mean_squared_error: 2.2745
# Epoch 50/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.2289 - y1_output_loss: 2.3887 - y2_output_loss: 5.1639 - y1_output_root_mean_squared_error: 1.4982 - y2_output_root_mean_squared_error: 2.2326 - val_loss: 125.2356 - val_y1_output_loss: 42.1377 - val_y2_output_loss: 86.3582 - val_y1_output_root_mean_squared_error: 6.3415 - val_y2_output_root_mean_squared_error: 9.2207
# Epoch 51/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.9042 - y1_output_loss: 2.8967 - y2_output_loss: 6.0118 - y1_output_root_mean_squared_error: 1.6973 - y2_output_root_mean_squared_error: 2.4542 - val_loss: 12.1215 - val_y1_output_loss: 4.6116 - val_y2_output_loss: 7.8924 - val_y1_output_root_mean_squared_error: 2.1368 - val_y2_output_root_mean_squared_error: 2.7488
# Epoch 52/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.0462 - y1_output_loss: 2.5133 - y2_output_loss: 5.5068 - y1_output_root_mean_squared_error: 1.5920 - y2_output_root_mean_squared_error: 2.3477 - val_loss: 8.5247 - val_y1_output_loss: 3.3057 - val_y2_output_loss: 5.0824 - val_y1_output_root_mean_squared_error: 1.8213 - val_y2_output_root_mean_squared_error: 2.2820
# Epoch 53/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.7728 - y1_output_loss: 2.5089 - y2_output_loss: 5.2047 - y1_output_root_mean_squared_error: 1.5876 - y2_output_root_mean_squared_error: 2.2918 - val_loss: 9.4894 - val_y1_output_loss: 3.4973 - val_y2_output_loss: 6.4391 - val_y1_output_root_mean_squared_error: 1.8364 - val_y2_output_root_mean_squared_error: 2.4733
# Epoch 54/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.2103 - y1_output_loss: 1.8568 - y2_output_loss: 4.3513 - y1_output_root_mean_squared_error: 1.3675 - y2_output_root_mean_squared_error: 2.0833 - val_loss: 7.8897 - val_y1_output_loss: 2.6347 - val_y2_output_loss: 5.3963 - val_y1_output_root_mean_squared_error: 1.6112 - val_y2_output_root_mean_squared_error: 2.3008
# Epoch 55/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.3120 - y1_output_loss: 2.0437 - y2_output_loss: 4.2703 - y1_output_root_mean_squared_error: 1.4359 - y2_output_root_mean_squared_error: 2.0616 - val_loss: 7.4687 - val_y1_output_loss: 2.3801 - val_y2_output_loss: 5.3584 - val_y1_output_root_mean_squared_error: 1.5170 - val_y2_output_root_mean_squared_error: 2.2732
# Epoch 56/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.8254 - y1_output_loss: 2.8623 - y2_output_loss: 5.8926 - y1_output_root_mean_squared_error: 1.6979 - y2_output_root_mean_squared_error: 2.4377 - val_loss: 10.5002 - val_y1_output_loss: 2.5779 - val_y2_output_loss: 7.7478 - val_y1_output_root_mean_squared_error: 1.5942 - val_y2_output_root_mean_squared_error: 2.8211
# Epoch 57/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.8237 - y1_output_loss: 2.2319 - y2_output_loss: 5.5340 - y1_output_root_mean_squared_error: 1.4981 - y2_output_root_mean_squared_error: 2.3621 - val_loss: 6.9382 - val_y1_output_loss: 2.0610 - val_y2_output_loss: 4.8818 - val_y1_output_root_mean_squared_error: 1.4217 - val_y2_output_root_mean_squared_error: 2.2174
# Epoch 58/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.2660 - y1_output_loss: 2.2594 - y2_output_loss: 5.0031 - y1_output_root_mean_squared_error: 1.4926 - y2_output_root_mean_squared_error: 2.2446 - val_loss: 10.2965 - val_y1_output_loss: 4.0345 - val_y2_output_loss: 6.0858 - val_y1_output_root_mean_squared_error: 2.0154 - val_y2_output_root_mean_squared_error: 2.4969
# Epoch 59/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.1042 - y1_output_loss: 1.9785 - y2_output_loss: 5.0963 - y1_output_root_mean_squared_error: 1.4087 - y2_output_root_mean_squared_error: 2.2627 - val_loss: 10.5246 - val_y1_output_loss: 3.2528 - val_y2_output_loss: 7.1286 - val_y1_output_root_mean_squared_error: 1.7931 - val_y2_output_root_mean_squared_error: 2.7036
# Epoch 60/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.3643 - y1_output_loss: 1.7431 - y2_output_loss: 3.6290 - y1_output_root_mean_squared_error: 1.3248 - y2_output_root_mean_squared_error: 1.8998 - val_loss: 10.9287 - val_y1_output_loss: 4.3711 - val_y2_output_loss: 6.8011 - val_y1_output_root_mean_squared_error: 2.0521 - val_y2_output_root_mean_squared_error: 2.5919
# Epoch 61/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.1799 - y1_output_loss: 2.0554 - y2_output_loss: 4.0837 - y1_output_root_mean_squared_error: 1.4386 - y2_output_root_mean_squared_error: 2.0274 - val_loss: 7.9089 - val_y1_output_loss: 2.5079 - val_y2_output_loss: 5.3430 - val_y1_output_root_mean_squared_error: 1.5716 - val_y2_output_root_mean_squared_error: 2.3322
# Epoch 62/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.1890 - y1_output_loss: 1.8377 - y2_output_loss: 4.2987 - y1_output_root_mean_squared_error: 1.3608 - y2_output_root_mean_squared_error: 2.0826 - val_loss: 6.5856 - val_y1_output_loss: 1.9534 - val_y2_output_loss: 4.5911 - val_y1_output_root_mean_squared_error: 1.3880 - val_y2_output_root_mean_squared_error: 2.1585
# Epoch 63/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.7618 - y1_output_loss: 1.9866 - y2_output_loss: 4.7469 - y1_output_root_mean_squared_error: 1.4125 - y2_output_root_mean_squared_error: 2.1832 - val_loss: 6.7952 - val_y1_output_loss: 2.4793 - val_y2_output_loss: 4.2140 - val_y1_output_root_mean_squared_error: 1.5793 - val_y2_output_root_mean_squared_error: 2.0739
# Epoch 64/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.8889 - y1_output_loss: 1.5861 - y2_output_loss: 3.2904 - y1_output_root_mean_squared_error: 1.2634 - y2_output_root_mean_squared_error: 1.8146 - val_loss: 8.0180 - val_y1_output_loss: 2.6965 - val_y2_output_loss: 5.1387 - val_y1_output_root_mean_squared_error: 1.6518 - val_y2_output_root_mean_squared_error: 2.2999
# Epoch 65/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.2257 - y1_output_loss: 1.6196 - y2_output_loss: 3.5947 - y1_output_root_mean_squared_error: 1.2740 - y2_output_root_mean_squared_error: 1.8981 - val_loss: 7.1514 - val_y1_output_loss: 2.5639 - val_y2_output_loss: 4.6997 - val_y1_output_root_mean_squared_error: 1.5862 - val_y2_output_root_mean_squared_error: 2.1530
# Epoch 66/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.0527 - y1_output_loss: 2.0410 - y2_output_loss: 4.9472 - y1_output_root_mean_squared_error: 1.4349 - y2_output_root_mean_squared_error: 2.2346 - val_loss: 7.1610 - val_y1_output_loss: 3.0037 - val_y2_output_loss: 4.2682 - val_y1_output_root_mean_squared_error: 1.7274 - val_y2_output_root_mean_squared_error: 2.0437
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.8949 - y1_output_loss: 1.9063 - y2_output_loss: 4.9363 - y1_output_root_mean_squared_error: 1.3869 - y2_output_root_mean_squared_error: 2.2296 - val_loss: 8.9529 - val_y1_output_loss: 2.4793 - val_y2_output_loss: 6.2979 - val_y1_output_root_mean_squared_error: 1.5741 - val_y2_output_root_mean_squared_error: 2.5446
# Epoch 68/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.4342 - y1_output_loss: 1.3224 - y2_output_loss: 3.0889 - y1_output_root_mean_squared_error: 1.1543 - y2_output_root_mean_squared_error: 1.7612 - val_loss: 6.3911 - val_y1_output_loss: 1.6702 - val_y2_output_loss: 4.8346 - val_y1_output_root_mean_squared_error: 1.2961 - val_y2_output_root_mean_squared_error: 2.1705
# Epoch 69/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.5598 - y1_output_loss: 1.5806 - y2_output_loss: 4.0211 - y1_output_root_mean_squared_error: 1.2602 - y2_output_root_mean_squared_error: 1.9929 - val_loss: 14.0865 - val_y1_output_loss: 2.6429 - val_y2_output_loss: 11.1585 - val_y1_output_root_mean_squared_error: 1.6232 - val_y2_output_root_mean_squared_error: 3.3840
# Epoch 70/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.9088 - y1_output_loss: 2.0784 - y2_output_loss: 4.8655 - y1_output_root_mean_squared_error: 1.4477 - y2_output_root_mean_squared_error: 2.1939 - val_loss: 19.2599 - val_y1_output_loss: 2.8702 - val_y2_output_loss: 16.9458 - val_y1_output_root_mean_squared_error: 1.6931 - val_y2_output_root_mean_squared_error: 4.0488
# Epoch 71/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.5802 - y1_output_loss: 2.6630 - y2_output_loss: 6.8606 - y1_output_root_mean_squared_error: 1.6377 - y2_output_root_mean_squared_error: 2.6265 - val_loss: 7.5703 - val_y1_output_loss: 1.8870 - val_y2_output_loss: 5.5307 - val_y1_output_root_mean_squared_error: 1.3700 - val_y2_output_root_mean_squared_error: 2.3861
# Epoch 72/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.2696 - y1_output_loss: 2.1606 - y2_output_loss: 6.1576 - y1_output_root_mean_squared_error: 1.4620 - y2_output_root_mean_squared_error: 2.4763 - val_loss: 19.7047 - val_y1_output_loss: 5.7845 - val_y2_output_loss: 14.7435 - val_y1_output_root_mean_squared_error: 2.3790 - val_y2_output_root_mean_squared_error: 3.7477
# Epoch 73/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.2610 - y1_output_loss: 1.7408 - y2_output_loss: 4.4623 - y1_output_root_mean_squared_error: 1.3254 - y2_output_root_mean_squared_error: 2.1223 - val_loss: 4.8115 - val_y1_output_loss: 1.3598 - val_y2_output_loss: 3.5193 - val_y1_output_root_mean_squared_error: 1.1704 - val_y2_output_root_mean_squared_error: 1.8552
# Epoch 74/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.7341 - y1_output_loss: 1.1490 - y2_output_loss: 2.5768 - y1_output_root_mean_squared_error: 1.0665 - y2_output_root_mean_squared_error: 1.6114 - val_loss: 5.6834 - val_y1_output_loss: 1.9268 - val_y2_output_loss: 3.9280 - val_y1_output_root_mean_squared_error: 1.3759 - val_y2_output_root_mean_squared_error: 1.9469
# Epoch 75/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.8677 - y1_output_loss: 1.3410 - y2_output_loss: 3.5337 - y1_output_root_mean_squared_error: 1.1512 - y2_output_root_mean_squared_error: 1.8822 - val_loss: 7.3671 - val_y1_output_loss: 2.1226 - val_y2_output_loss: 5.4524 - val_y1_output_root_mean_squared_error: 1.4587 - val_y2_output_root_mean_squared_error: 2.2890
# Epoch 76/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.1746 - y1_output_loss: 1.1660 - y2_output_loss: 3.0406 - y1_output_root_mean_squared_error: 1.0829 - y2_output_root_mean_squared_error: 1.7326 - val_loss: 6.1566 - val_y1_output_loss: 1.9020 - val_y2_output_loss: 4.4300 - val_y1_output_root_mean_squared_error: 1.3719 - val_y2_output_root_mean_squared_error: 2.0675
# Epoch 77/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0892 - y1_output_loss: 1.1259 - y2_output_loss: 2.9661 - y1_output_root_mean_squared_error: 1.0619 - y2_output_root_mean_squared_error: 1.7209 - val_loss: 8.1109 - val_y1_output_loss: 2.1002 - val_y2_output_loss: 6.2519 - val_y1_output_root_mean_squared_error: 1.4545 - val_y2_output_root_mean_squared_error: 2.4486
# Epoch 78/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.3317 - y1_output_loss: 1.2571 - y2_output_loss: 3.0396 - y1_output_root_mean_squared_error: 1.1252 - y2_output_root_mean_squared_error: 1.7509 - val_loss: 5.1466 - val_y1_output_loss: 1.2598 - val_y2_output_loss: 3.7798 - val_y1_output_root_mean_squared_error: 1.1294 - val_y2_output_root_mean_squared_error: 1.9675
# Epoch 79/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3093 - y1_output_loss: 0.8947 - y2_output_loss: 2.4791 - y1_output_root_mean_squared_error: 0.9496 - y2_output_root_mean_squared_error: 1.5516 - val_loss: 12.5412 - val_y1_output_loss: 2.2128 - val_y2_output_loss: 10.7055 - val_y1_output_root_mean_squared_error: 1.4941 - val_y2_output_root_mean_squared_error: 3.2108
# Epoch 80/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7730 - y1_output_loss: 0.9713 - y2_output_loss: 2.7764 - y1_output_root_mean_squared_error: 0.9858 - y2_output_root_mean_squared_error: 1.6737 - val_loss: 5.4335 - val_y1_output_loss: 1.3874 - val_y2_output_loss: 3.9394 - val_y1_output_root_mean_squared_error: 1.1760 - val_y2_output_root_mean_squared_error: 2.0126
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5546 - y1_output_loss: 1.2231 - y2_output_loss: 3.3230 - y1_output_root_mean_squared_error: 1.1105 - y2_output_root_mean_squared_error: 1.8225 - val_loss: 4.7803 - val_y1_output_loss: 1.2044 - val_y2_output_loss: 3.6909 - val_y1_output_root_mean_squared_error: 1.0906 - val_y2_output_root_mean_squared_error: 1.8949
# Epoch 82/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4873 - y1_output_loss: 0.9401 - y2_output_loss: 2.5500 - y1_output_root_mean_squared_error: 0.9668 - y2_output_root_mean_squared_error: 1.5976 - val_loss: 7.7429 - val_y1_output_loss: 1.8166 - val_y2_output_loss: 6.2573 - val_y1_output_root_mean_squared_error: 1.3371 - val_y2_output_root_mean_squared_error: 2.4403
# Epoch 83/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.5588 - y1_output_loss: 1.3017 - y2_output_loss: 3.2710 - y1_output_root_mean_squared_error: 1.1430 - y2_output_root_mean_squared_error: 1.8034 - val_loss: 7.6789 - val_y1_output_loss: 2.0060 - val_y2_output_loss: 5.9906 - val_y1_output_root_mean_squared_error: 1.4108 - val_y2_output_root_mean_squared_error: 2.3851
# Epoch 84/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.1938 - y1_output_loss: 1.1121 - y2_output_loss: 3.0880 - y1_output_root_mean_squared_error: 1.0574 - y2_output_root_mean_squared_error: 1.7538 - val_loss: 5.6005 - val_y1_output_loss: 1.0238 - val_y2_output_loss: 4.4197 - val_y1_output_root_mean_squared_error: 1.0162 - val_y2_output_root_mean_squared_error: 2.1373
# Epoch 85/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.7376 - y1_output_loss: 0.9288 - y2_output_loss: 2.8628 - y1_output_root_mean_squared_error: 0.9551 - y2_output_root_mean_squared_error: 1.6809 - val_loss: 12.1262 - val_y1_output_loss: 5.5085 - val_y2_output_loss: 7.0490 - val_y1_output_root_mean_squared_error: 2.3216 - val_y2_output_root_mean_squared_error: 2.5954
# Epoch 86/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0926 - y1_output_loss: 1.1747 - y2_output_loss: 2.9064 - y1_output_root_mean_squared_error: 1.0792 - y2_output_root_mean_squared_error: 1.7111 - val_loss: 5.9180 - val_y1_output_loss: 1.6069 - val_y2_output_loss: 4.2555 - val_y1_output_root_mean_squared_error: 1.2553 - val_y2_output_root_mean_squared_error: 2.0838
# Epoch 87/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4175 - y1_output_loss: 0.7856 - y2_output_loss: 2.6032 - y1_output_root_mean_squared_error: 0.8899 - y2_output_root_mean_squared_error: 1.6204 - val_loss: 3.4773 - val_y1_output_loss: 0.9026 - val_y2_output_loss: 2.5598 - val_y1_output_root_mean_squared_error: 0.9567 - val_y2_output_root_mean_squared_error: 1.6006
# Epoch 88/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.8382 - y1_output_loss: 1.1657 - y2_output_loss: 3.6763 - y1_output_root_mean_squared_error: 1.0755 - y2_output_root_mean_squared_error: 1.9187 - val_loss: 8.9787 - val_y1_output_loss: 2.2900 - val_y2_output_loss: 6.6187 - val_y1_output_root_mean_squared_error: 1.4944 - val_y2_output_root_mean_squared_error: 2.5972
# Epoch 89/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8366 - y1_output_loss: 0.6505 - y2_output_loss: 2.1622 - y1_output_root_mean_squared_error: 0.8099 - y2_output_root_mean_squared_error: 1.4767 - val_loss: 3.7071 - val_y1_output_loss: 0.8254 - val_y2_output_loss: 2.8806 - val_y1_output_root_mean_squared_error: 0.9105 - val_y2_output_root_mean_squared_error: 1.6965
# Epoch 90/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7983 - y1_output_loss: 0.7302 - y2_output_loss: 2.0867 - y1_output_root_mean_squared_error: 0.8458 - y2_output_root_mean_squared_error: 1.4433 - val_loss: 11.3937 - val_y1_output_loss: 3.7547 - val_y2_output_loss: 7.6935 - val_y1_output_root_mean_squared_error: 1.8983 - val_y2_output_root_mean_squared_error: 2.7911
# Epoch 91/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.5779 - y1_output_loss: 1.2584 - y2_output_loss: 3.3099 - y1_output_root_mean_squared_error: 1.1242 - y2_output_root_mean_squared_error: 1.8204 - val_loss: 4.2711 - val_y1_output_loss: 0.9217 - val_y2_output_loss: 3.5532 - val_y1_output_root_mean_squared_error: 0.9520 - val_y2_output_root_mean_squared_error: 1.8343
# Epoch 92/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4546 - y1_output_loss: 0.8928 - y2_output_loss: 2.5383 - y1_output_root_mean_squared_error: 0.9458 - y2_output_root_mean_squared_error: 1.6000 - val_loss: 3.4393 - val_y1_output_loss: 0.8823 - val_y2_output_loss: 2.5536 - val_y1_output_root_mean_squared_error: 0.9435 - val_y2_output_root_mean_squared_error: 1.5966
# Epoch 93/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0193 - y1_output_loss: 0.7662 - y2_output_loss: 2.3503 - y1_output_root_mean_squared_error: 0.8737 - y2_output_root_mean_squared_error: 1.5020 - val_loss: 24.1950 - val_y1_output_loss: 4.0032 - val_y2_output_loss: 19.9221 - val_y1_output_root_mean_squared_error: 1.9925 - val_y2_output_root_mean_squared_error: 4.4972
# Epoch 94/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.6456 - y1_output_loss: 0.8566 - y2_output_loss: 2.7697 - y1_output_root_mean_squared_error: 0.9280 - y2_output_root_mean_squared_error: 1.6687 - val_loss: 3.4649 - val_y1_output_loss: 0.7596 - val_y2_output_loss: 2.6388 - val_y1_output_root_mean_squared_error: 0.8802 - val_y2_output_root_mean_squared_error: 1.6402
# Epoch 95/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6453 - y1_output_loss: 0.6286 - y2_output_loss: 2.0178 - y1_output_root_mean_squared_error: 0.7931 - y2_output_root_mean_squared_error: 1.4200 - val_loss: 5.2942 - val_y1_output_loss: 1.2604 - val_y2_output_loss: 4.2116 - val_y1_output_root_mean_squared_error: 1.1314 - val_y2_output_root_mean_squared_error: 2.0035
# Epoch 96/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9204 - y1_output_loss: 0.7051 - y2_output_loss: 2.2347 - y1_output_root_mean_squared_error: 0.8411 - y2_output_root_mean_squared_error: 1.4876 - val_loss: 21.4572 - val_y1_output_loss: 3.3315 - val_y2_output_loss: 18.8738 - val_y1_output_root_mean_squared_error: 1.8162 - val_y2_output_root_mean_squared_error: 4.2613
# Epoch 97/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.1168 - y1_output_loss: 1.0305 - y2_output_loss: 3.0499 - y1_output_root_mean_squared_error: 1.0185 - y2_output_root_mean_squared_error: 1.7548 - val_loss: 4.0987 - val_y1_output_loss: 0.9640 - val_y2_output_loss: 3.1461 - val_y1_output_root_mean_squared_error: 0.9698 - val_y2_output_root_mean_squared_error: 1.7771
# Epoch 98/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9804 - y1_output_loss: 0.8087 - y2_output_loss: 2.1700 - y1_output_root_mean_squared_error: 0.8991 - y2_output_root_mean_squared_error: 1.4738 - val_loss: 7.2178 - val_y1_output_loss: 2.5597 - val_y2_output_loss: 5.0216 - val_y1_output_root_mean_squared_error: 1.5787 - val_y2_output_root_mean_squared_error: 2.1738
# Epoch 99/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.2005 - y1_output_loss: 0.5707 - y2_output_loss: 1.6182 - y1_output_root_mean_squared_error: 0.7574 - y2_output_root_mean_squared_error: 1.2755 - val_loss: 5.8562 - val_y1_output_loss: 1.0023 - val_y2_output_loss: 4.7373 - val_y1_output_root_mean_squared_error: 0.9978 - val_y2_output_root_mean_squared_error: 2.2047
# Epoch 100/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5565 - y1_output_loss: 0.6112 - y2_output_loss: 1.9413 - y1_output_root_mean_squared_error: 0.7759 - y2_output_root_mean_squared_error: 1.3980 - val_loss: 2.9335 - val_y1_output_loss: 0.6221 - val_y2_output_loss: 2.2980 - val_y1_output_root_mean_squared_error: 0.7963 - val_y2_output_root_mean_squared_error: 1.5163
# Epoch 101/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.8132 - y1_output_loss: 0.6656 - y2_output_loss: 2.1563 - y1_output_root_mean_squared_error: 0.8152 - y2_output_root_mean_squared_error: 1.4659 - val_loss: 6.2269 - val_y1_output_loss: 1.2106 - val_y2_output_loss: 4.9436 - val_y1_output_root_mean_squared_error: 1.0887 - val_y2_output_root_mean_squared_error: 2.2454
# Epoch 102/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.0359 - y1_output_loss: 0.7865 - y2_output_loss: 2.2671 - y1_output_root_mean_squared_error: 0.8892 - y2_output_root_mean_squared_error: 1.4984 - val_loss: 8.8658 - val_y1_output_loss: 1.4583 - val_y2_output_loss: 7.2964 - val_y1_output_root_mean_squared_error: 1.1937 - val_y2_output_root_mean_squared_error: 2.7278
# Epoch 103/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.3583 - y1_output_loss: 0.8222 - y2_output_loss: 2.5057 - y1_output_root_mean_squared_error: 0.9103 - y2_output_root_mean_squared_error: 1.5905 - val_loss: 3.3708 - val_y1_output_loss: 0.5533 - val_y2_output_loss: 2.7428 - val_y1_output_root_mean_squared_error: 0.7478 - val_y2_output_root_mean_squared_error: 1.6768
# Epoch 104/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3959 - y1_output_loss: 0.5652 - y2_output_loss: 1.8448 - y1_output_root_mean_squared_error: 0.7508 - y2_output_root_mean_squared_error: 1.3536 - val_loss: 4.4813 - val_y1_output_loss: 1.2081 - val_y2_output_loss: 3.3578 - val_y1_output_root_mean_squared_error: 1.1131 - val_y2_output_root_mean_squared_error: 1.8007
# Epoch 105/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3613 - y1_output_loss: 0.5988 - y2_output_loss: 1.7750 - y1_output_root_mean_squared_error: 0.7749 - y2_output_root_mean_squared_error: 1.3270 - val_loss: 12.4569 - val_y1_output_loss: 3.0315 - val_y2_output_loss: 9.4661 - val_y1_output_root_mean_squared_error: 1.7115 - val_y2_output_root_mean_squared_error: 3.0867
# Epoch 106/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.8910 - y1_output_loss: 0.9594 - y2_output_loss: 3.0105 - y1_output_root_mean_squared_error: 0.9745 - y2_output_root_mean_squared_error: 1.7151 - val_loss: 22.4399 - val_y1_output_loss: 7.2820 - val_y2_output_loss: 15.5253 - val_y1_output_root_mean_squared_error: 2.7061 - val_y2_output_root_mean_squared_error: 3.8880
# Epoch 107/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.2498 - y1_output_loss: 1.2375 - y2_output_loss: 2.9930 - y1_output_root_mean_squared_error: 1.1110 - y2_output_root_mean_squared_error: 1.7365 - val_loss: 3.9403 - val_y1_output_loss: 1.2784 - val_y2_output_loss: 2.6706 - val_y1_output_root_mean_squared_error: 1.1391 - val_y2_output_root_mean_squared_error: 1.6257
# Epoch 108/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.1635 - y1_output_loss: 0.4722 - y2_output_loss: 1.6831 - y1_output_root_mean_squared_error: 0.6857 - y2_output_root_mean_squared_error: 1.3013 - val_loss: 4.2434 - val_y1_output_loss: 1.0835 - val_y2_output_loss: 3.3100 - val_y1_output_root_mean_squared_error: 1.0345 - val_y2_output_root_mean_squared_error: 1.7813
# Epoch 109/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.1405 - y1_output_loss: 0.5001 - y2_output_loss: 1.6480 - y1_output_root_mean_squared_error: 0.6946 - y2_output_root_mean_squared_error: 1.2876 - val_loss: 3.6965 - val_y1_output_loss: 1.0206 - val_y2_output_loss: 2.6203 - val_y1_output_root_mean_squared_error: 1.0031 - val_y2_output_root_mean_squared_error: 1.6402
# Epoch 110/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2726 - y1_output_loss: 0.6796 - y2_output_loss: 1.6549 - y1_output_root_mean_squared_error: 0.8258 - y2_output_root_mean_squared_error: 1.2612 - val_loss: 13.5377 - val_y1_output_loss: 2.9721 - val_y2_output_loss: 10.8107 - val_y1_output_root_mean_squared_error: 1.7365 - val_y2_output_root_mean_squared_error: 3.2438
# Epoch 111/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3875 - y1_output_loss: 1.2261 - y2_output_loss: 3.1656 - y1_output_root_mean_squared_error: 1.1122 - y2_output_root_mean_squared_error: 1.7749 - val_loss: 4.7508 - val_y1_output_loss: 0.5579 - val_y2_output_loss: 4.3441 - val_y1_output_root_mean_squared_error: 0.7561 - val_y2_output_root_mean_squared_error: 2.0443
# Epoch 112/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6021 - y1_output_loss: 0.6106 - y2_output_loss: 1.9794 - y1_output_root_mean_squared_error: 0.7825 - y2_output_root_mean_squared_error: 1.4106 - val_loss: 3.4970 - val_y1_output_loss: 1.0387 - val_y2_output_loss: 2.4733 - val_y1_output_root_mean_squared_error: 1.0284 - val_y2_output_root_mean_squared_error: 1.5619
# Epoch 113/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.0805 - y1_output_loss: 0.4527 - y2_output_loss: 1.6442 - y1_output_root_mean_squared_error: 0.6711 - y2_output_root_mean_squared_error: 1.2768 - val_loss: 6.4247 - val_y1_output_loss: 1.0949 - val_y2_output_loss: 5.1471 - val_y1_output_root_mean_squared_error: 1.0515 - val_y2_output_root_mean_squared_error: 2.3063
# Epoch 114/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.0643 - y1_output_loss: 0.4574 - y2_output_loss: 1.6049 - y1_output_root_mean_squared_error: 0.6774 - y2_output_root_mean_squared_error: 1.2670 - val_loss: 3.1321 - val_y1_output_loss: 0.6325 - val_y2_output_loss: 2.4389 - val_y1_output_root_mean_squared_error: 0.8040 - val_y2_output_root_mean_squared_error: 1.5766
# Epoch 115/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.1436 - y1_output_loss: 0.4556 - y2_output_loss: 1.6749 - y1_output_root_mean_squared_error: 0.6764 - y2_output_root_mean_squared_error: 1.2985 - val_loss: 2.6542 - val_y1_output_loss: 0.6293 - val_y2_output_loss: 1.9897 - val_y1_output_root_mean_squared_error: 0.8002 - val_y2_output_root_mean_squared_error: 1.4191
# Epoch 116/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.1620 - y1_output_loss: 0.5753 - y2_output_loss: 1.6142 - y1_output_root_mean_squared_error: 0.7557 - y2_output_root_mean_squared_error: 1.2613 - val_loss: 3.9429 - val_y1_output_loss: 1.5553 - val_y2_output_loss: 2.4542 - val_y1_output_root_mean_squared_error: 1.2544 - val_y2_output_root_mean_squared_error: 1.5393
# Epoch 117/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.0898 - y1_output_loss: 0.5132 - y2_output_loss: 1.5688 - y1_output_root_mean_squared_error: 0.7160 - y2_output_root_mean_squared_error: 1.2558 - val_loss: 2.7198 - val_y1_output_loss: 0.6683 - val_y2_output_loss: 2.0489 - val_y1_output_root_mean_squared_error: 0.8261 - val_y2_output_root_mean_squared_error: 1.4273
# Epoch 118/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.5689 - y1_output_loss: 0.8078 - y2_output_loss: 2.7463 - y1_output_root_mean_squared_error: 0.8952 - y2_output_root_mean_squared_error: 1.6636 - val_loss: 2.8408 - val_y1_output_loss: 0.5125 - val_y2_output_loss: 2.2686 - val_y1_output_root_mean_squared_error: 0.7176 - val_y2_output_root_mean_squared_error: 1.5251
# Epoch 119/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.9422 - y1_output_loss: 0.4225 - y2_output_loss: 1.5158 - y1_output_root_mean_squared_error: 0.6501 - y2_output_root_mean_squared_error: 1.2327 - val_loss: 2.5213 - val_y1_output_loss: 0.6045 - val_y2_output_loss: 1.8716 - val_y1_output_root_mean_squared_error: 0.7875 - val_y2_output_root_mean_squared_error: 1.3788
# Epoch 120/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.9531 - y1_output_loss: 0.4747 - y2_output_loss: 1.4753 - y1_output_root_mean_squared_error: 0.6870 - y2_output_root_mean_squared_error: 1.2170 - val_loss: 3.0700 - val_y1_output_loss: 0.5724 - val_y2_output_loss: 2.5684 - val_y1_output_root_mean_squared_error: 0.7656 - val_y2_output_root_mean_squared_error: 1.5760
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4820 - y1_output_loss: 0.1281 - y2_output_loss: 0.3495 - y1_output_root_mean_squared_error: 0.3597 - y2_output_root_mean_squared_error: 0.5939 - val_loss: 0.6423 - val_y1_output_loss: 0.1817 - val_y2_output_loss: 0.4663 - val_y1_output_root_mean_squared_error: 0.4175 - val_y2_output_root_mean_squared_error: 0.6841
# Epoch 462/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3744 - y1_output_loss: 0.1236 - y2_output_loss: 0.2484 - y1_output_root_mean_squared_error: 0.3531 - y2_output_root_mean_squared_error: 0.4997 - val_loss: 0.6263 - val_y1_output_loss: 0.1551 - val_y2_output_loss: 0.4824 - val_y1_output_root_mean_squared_error: 0.3939 - val_y2_output_root_mean_squared_error: 0.6864
# Epoch 463/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3811 - y1_output_loss: 0.1227 - y2_output_loss: 0.2618 - y1_output_root_mean_squared_error: 0.3501 - y2_output_root_mean_squared_error: 0.5085 - val_loss: 0.7578 - val_y1_output_loss: 0.1818 - val_y2_output_loss: 0.5866 - val_y1_output_root_mean_squared_error: 0.4196 - val_y2_output_root_mean_squared_error: 0.7627
# Epoch 464/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4359 - y1_output_loss: 0.1373 - y2_output_loss: 0.2976 - y1_output_root_mean_squared_error: 0.3709 - y2_output_root_mean_squared_error: 0.5462 - val_loss: 0.8900 - val_y1_output_loss: 0.2746 - val_y2_output_loss: 0.6244 - val_y1_output_root_mean_squared_error: 0.5244 - val_y2_output_root_mean_squared_error: 0.7842
# Epoch 465/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4339 - y1_output_loss: 0.1290 - y2_output_loss: 0.3014 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.5513 - val_loss: 0.7111 - val_y1_output_loss: 0.1548 - val_y2_output_loss: 0.5535 - val_y1_output_root_mean_squared_error: 0.3888 - val_y2_output_root_mean_squared_error: 0.7483
# Epoch 466/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4838 - y1_output_loss: 0.1357 - y2_output_loss: 0.3451 - y1_output_root_mean_squared_error: 0.3691 - y2_output_root_mean_squared_error: 0.5896 - val_loss: 0.8550 - val_y1_output_loss: 0.1794 - val_y2_output_loss: 0.6615 - val_y1_output_root_mean_squared_error: 0.4266 - val_y2_output_root_mean_squared_error: 0.8204
# Epoch 467/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5537 - y1_output_loss: 0.1500 - y2_output_loss: 0.4053 - y1_output_root_mean_squared_error: 0.3874 - y2_output_root_mean_squared_error: 0.6353 - val_loss: 0.9668 - val_y1_output_loss: 0.1843 - val_y2_output_loss: 0.8050 - val_y1_output_root_mean_squared_error: 0.4158 - val_y2_output_root_mean_squared_error: 0.8910
# Epoch 468/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5053 - y1_output_loss: 0.1304 - y2_output_loss: 0.3819 - y1_output_root_mean_squared_error: 0.3622 - y2_output_root_mean_squared_error: 0.6117 - val_loss: 1.0321 - val_y1_output_loss: 0.1976 - val_y2_output_loss: 0.8109 - val_y1_output_root_mean_squared_error: 0.4471 - val_y2_output_root_mean_squared_error: 0.9123
# Epoch 469/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3806 - y1_output_loss: 0.1173 - y2_output_loss: 0.2609 - y1_output_root_mean_squared_error: 0.3437 - y2_output_root_mean_squared_error: 0.5123 - val_loss: 0.6865 - val_y1_output_loss: 0.1398 - val_y2_output_loss: 0.5385 - val_y1_output_root_mean_squared_error: 0.3720 - val_y2_output_root_mean_squared_error: 0.7403
# Epoch 470/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4799 - y1_output_loss: 0.1518 - y2_output_loss: 0.3261 - y1_output_root_mean_squared_error: 0.3900 - y2_output_root_mean_squared_error: 0.5725 - val_loss: 0.8730 - val_y1_output_loss: 0.1841 - val_y2_output_loss: 0.6789 - val_y1_output_root_mean_squared_error: 0.4219 - val_y2_output_root_mean_squared_error: 0.8337
# Epoch 471/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.6352 - y1_output_loss: 0.1695 - y2_output_loss: 0.4620 - y1_output_root_mean_squared_error: 0.4127 - y2_output_root_mean_squared_error: 0.6818 - val_loss: 0.7027 - val_y1_output_loss: 0.1817 - val_y2_output_loss: 0.5377 - val_y1_output_root_mean_squared_error: 0.4264 - val_y2_output_root_mean_squared_error: 0.7217
# Epoch 472/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4527 - y1_output_loss: 0.1477 - y2_output_loss: 0.3067 - y1_output_root_mean_squared_error: 0.3849 - y2_output_root_mean_squared_error: 0.5519 - val_loss: 1.7146 - val_y1_output_loss: 0.1535 - val_y2_output_loss: 1.5342 - val_y1_output_root_mean_squared_error: 0.3877 - val_y2_output_root_mean_squared_error: 1.2507
# Epoch 473/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4646 - y1_output_loss: 0.1458 - y2_output_loss: 0.3152 - y1_output_root_mean_squared_error: 0.3832 - y2_output_root_mean_squared_error: 0.5637 - val_loss: 0.6346 - val_y1_output_loss: 0.1404 - val_y2_output_loss: 0.4944 - val_y1_output_root_mean_squared_error: 0.3720 - val_y2_output_root_mean_squared_error: 0.7045
# Epoch 474/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5460 - y1_output_loss: 0.1460 - y2_output_loss: 0.3975 - y1_output_root_mean_squared_error: 0.3817 - y2_output_root_mean_squared_error: 0.6327 - val_loss: 0.6738 - val_y1_output_loss: 0.1995 - val_y2_output_loss: 0.4739 - val_y1_output_root_mean_squared_error: 0.4458 - val_y2_output_root_mean_squared_error: 0.6893
# Epoch 475/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5104 - y1_output_loss: 0.1582 - y2_output_loss: 0.3512 - y1_output_root_mean_squared_error: 0.3989 - y2_output_root_mean_squared_error: 0.5926 - val_loss: 0.8362 - val_y1_output_loss: 0.2140 - val_y2_output_loss: 0.6086 - val_y1_output_root_mean_squared_error: 0.4629 - val_y2_output_root_mean_squared_error: 0.7886
# Epoch 476/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3280 - y1_output_loss: 0.1078 - y2_output_loss: 0.2217 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4706 - val_loss: 0.7783 - val_y1_output_loss: 0.1572 - val_y2_output_loss: 0.6108 - val_y1_output_root_mean_squared_error: 0.3936 - val_y2_output_root_mean_squared_error: 0.7895
# Epoch 477/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4427 - y1_output_loss: 0.1250 - y2_output_loss: 0.3188 - y1_output_root_mean_squared_error: 0.3545 - y2_output_root_mean_squared_error: 0.5630 - val_loss: 1.4876 - val_y1_output_loss: 0.1589 - val_y2_output_loss: 1.2975 - val_y1_output_root_mean_squared_error: 0.3985 - val_y2_output_root_mean_squared_error: 1.1527
# Epoch 478/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4657 - y1_output_loss: 0.1377 - y2_output_loss: 0.3273 - y1_output_root_mean_squared_error: 0.3716 - y2_output_root_mean_squared_error: 0.5723 - val_loss: 0.8409 - val_y1_output_loss: 0.2294 - val_y2_output_loss: 0.6176 - val_y1_output_root_mean_squared_error: 0.4712 - val_y2_output_root_mean_squared_error: 0.7867
# Epoch 479/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4155 - y1_output_loss: 0.1236 - y2_output_loss: 0.2894 - y1_output_root_mean_squared_error: 0.3527 - y2_output_root_mean_squared_error: 0.5395 - val_loss: 0.6810 - val_y1_output_loss: 0.1576 - val_y2_output_loss: 0.5240 - val_y1_output_root_mean_squared_error: 0.3976 - val_y2_output_root_mean_squared_error: 0.7231
# Epoch 480/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5205 - y1_output_loss: 0.1580 - y2_output_loss: 0.3628 - y1_output_root_mean_squared_error: 0.3982 - y2_output_root_mean_squared_error: 0.6016 - val_loss: 0.7007 - val_y1_output_loss: 0.1599 - val_y2_output_loss: 0.5599 - val_y1_output_root_mean_squared_error: 0.3985 - val_y2_output_root_mean_squared_error: 0.7361
# Epoch 481/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5227 - y1_output_loss: 0.1489 - y2_output_loss: 0.3708 - y1_output_root_mean_squared_error: 0.3866 - y2_output_root_mean_squared_error: 0.6109 - val_loss: 0.6154 - val_y1_output_loss: 0.1423 - val_y2_output_loss: 0.4684 - val_y1_output_root_mean_squared_error: 0.3760 - val_y2_output_root_mean_squared_error: 0.6885
# Epoch 482/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4029 - y1_output_loss: 0.1381 - y2_output_loss: 0.2775 - y1_output_root_mean_squared_error: 0.3653 - y2_output_root_mean_squared_error: 0.5190 - val_loss: 2.3103 - val_y1_output_loss: 0.4447 - val_y2_output_loss: 1.8041 - val_y1_output_root_mean_squared_error: 0.6725 - val_y2_output_root_mean_squared_error: 1.3631
# Epoch 483/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4622 - y1_output_loss: 0.1522 - y2_output_loss: 0.3071 - y1_output_root_mean_squared_error: 0.3910 - y2_output_root_mean_squared_error: 0.5562 - val_loss: 0.6657 - val_y1_output_loss: 0.1801 - val_y2_output_loss: 0.4950 - val_y1_output_root_mean_squared_error: 0.4214 - val_y2_output_root_mean_squared_error: 0.6987
# Epoch 484/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3634 - y1_output_loss: 0.1155 - y2_output_loss: 0.2453 - y1_output_root_mean_squared_error: 0.3405 - y2_output_root_mean_squared_error: 0.4974 - val_loss: 0.5640 - val_y1_output_loss: 0.1393 - val_y2_output_loss: 0.4256 - val_y1_output_root_mean_squared_error: 0.3731 - val_y2_output_root_mean_squared_error: 0.6518
# Epoch 485/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4060 - y1_output_loss: 0.1606 - y2_output_loss: 0.2683 - y1_output_root_mean_squared_error: 0.3810 - y2_output_root_mean_squared_error: 0.5108 - val_loss: 2.8546 - val_y1_output_loss: 1.0929 - val_y2_output_loss: 1.7993 - val_y1_output_root_mean_squared_error: 1.0227 - val_y2_output_root_mean_squared_error: 1.3449
# Epoch 486/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5195 - y1_output_loss: 0.1653 - y2_output_loss: 0.3545 - y1_output_root_mean_squared_error: 0.4067 - y2_output_root_mean_squared_error: 0.5951 - val_loss: 0.7849 - val_y1_output_loss: 0.1846 - val_y2_output_loss: 0.6031 - val_y1_output_root_mean_squared_error: 0.4238 - val_y2_output_root_mean_squared_error: 0.7780
# Epoch 487/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3523 - y1_output_loss: 0.1126 - y2_output_loss: 0.2390 - y1_output_root_mean_squared_error: 0.3369 - y2_output_root_mean_squared_error: 0.4887 - val_loss: 1.2492 - val_y1_output_loss: 0.1771 - val_y2_output_loss: 1.0493 - val_y1_output_root_mean_squared_error: 0.4177 - val_y2_output_root_mean_squared_error: 1.0367
# Epoch 488/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4200 - y1_output_loss: 0.1356 - y2_output_loss: 0.2866 - y1_output_root_mean_squared_error: 0.3629 - y2_output_root_mean_squared_error: 0.5370 - val_loss: 1.0591 - val_y1_output_loss: 0.4383 - val_y2_output_loss: 0.6336 - val_y1_output_root_mean_squared_error: 0.6441 - val_y2_output_root_mean_squared_error: 0.8026
# Epoch 489/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4720 - y1_output_loss: 0.1603 - y2_output_loss: 0.3138 - y1_output_root_mean_squared_error: 0.3974 - y2_output_root_mean_squared_error: 0.5604 - val_loss: 1.1143 - val_y1_output_loss: 0.3268 - val_y2_output_loss: 0.8208 - val_y1_output_root_mean_squared_error: 0.5657 - val_y2_output_root_mean_squared_error: 0.8912
# Epoch 490/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4804 - y1_output_loss: 0.1404 - y2_output_loss: 0.3382 - y1_output_root_mean_squared_error: 0.3744 - y2_output_root_mean_squared_error: 0.5833 - val_loss: 0.7315 - val_y1_output_loss: 0.1458 - val_y2_output_loss: 0.5822 - val_y1_output_root_mean_squared_error: 0.3791 - val_y2_output_root_mean_squared_error: 0.7667
# Epoch 491/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3960 - y1_output_loss: 0.1201 - y2_output_loss: 0.2742 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.5249 - val_loss: 0.6293 - val_y1_output_loss: 0.1382 - val_y2_output_loss: 0.5004 - val_y1_output_root_mean_squared_error: 0.3713 - val_y2_output_root_mean_squared_error: 0.7010
# Epoch 492/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3861 - y1_output_loss: 0.1100 - y2_output_loss: 0.2729 - y1_output_root_mean_squared_error: 0.3330 - y2_output_root_mean_squared_error: 0.5246 - val_loss: 0.6360 - val_y1_output_loss: 0.1501 - val_y2_output_loss: 0.4783 - val_y1_output_root_mean_squared_error: 0.3889 - val_y2_output_root_mean_squared_error: 0.6962
# Epoch 493/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3890 - y1_output_loss: 0.1256 - y2_output_loss: 0.2617 - y1_output_root_mean_squared_error: 0.3544 - y2_output_root_mean_squared_error: 0.5132 - val_loss: 0.6512 - val_y1_output_loss: 0.1584 - val_y2_output_loss: 0.4839 - val_y1_output_root_mean_squared_error: 0.3990 - val_y2_output_root_mean_squared_error: 0.7014
# Epoch 494/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4753 - y1_output_loss: 0.1313 - y2_output_loss: 0.3409 - y1_output_root_mean_squared_error: 0.3633 - y2_output_root_mean_squared_error: 0.5859 - val_loss: 0.7297 - val_y1_output_loss: 0.1405 - val_y2_output_loss: 0.5821 - val_y1_output_root_mean_squared_error: 0.3731 - val_y2_output_root_mean_squared_error: 0.7685
# Epoch 495/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4212 - y1_output_loss: 0.1421 - y2_output_loss: 0.2874 - y1_output_root_mean_squared_error: 0.3749 - y2_output_root_mean_squared_error: 0.5298 - val_loss: 0.8992 - val_y1_output_loss: 0.1980 - val_y2_output_loss: 0.7154 - val_y1_output_root_mean_squared_error: 0.4433 - val_y2_output_root_mean_squared_error: 0.8383
# Epoch 496/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4488 - y1_output_loss: 0.1330 - y2_output_loss: 0.3121 - y1_output_root_mean_squared_error: 0.3661 - y2_output_root_mean_squared_error: 0.5611 - val_loss: 0.5595 - val_y1_output_loss: 0.1360 - val_y2_output_loss: 0.4248 - val_y1_output_root_mean_squared_error: 0.3679 - val_y2_output_root_mean_squared_error: 0.6513
# Epoch 497/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4014 - y1_output_loss: 0.1242 - y2_output_loss: 0.2756 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5272 - val_loss: 0.7047 - val_y1_output_loss: 0.1923 - val_y2_output_loss: 0.5217 - val_y1_output_root_mean_squared_error: 0.4382 - val_y2_output_root_mean_squared_error: 0.7160
# Epoch 498/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3724 - y1_output_loss: 0.1272 - y2_output_loss: 0.2441 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.4946 - val_loss: 1.2914 - val_y1_output_loss: 0.2246 - val_y2_output_loss: 1.1035 - val_y1_output_root_mean_squared_error: 0.4697 - val_y2_output_root_mean_squared_error: 1.0348
# Epoch 499/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5204 - y1_output_loss: 0.1286 - y2_output_loss: 0.3879 - y1_output_root_mean_squared_error: 0.3602 - y2_output_root_mean_squared_error: 0.6250 - val_loss: 0.6918 - val_y1_output_loss: 0.1681 - val_y2_output_loss: 0.5160 - val_y1_output_root_mean_squared_error: 0.4102 - val_y2_output_root_mean_squared_error: 0.7235
# Epoch 500/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3536 - y1_output_loss: 0.1146 - y2_output_loss: 0.2366 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.4882 - val_loss: 0.6288 - val_y1_output_loss: 0.1509 - val_y2_output_loss: 0.4755 - val_y1_output_root_mean_squared_error: 0.3891 - val_y2_output_root_mean_squared_error: 0.6909

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 0.6288 - y1_output_loss: 0.1515 - y2_output_loss: 0.4829 - y1_output_root_mean_squared_error: 0.3891 - y2_output_root_mean_squared_error: 0.6909
# Loss = 0.6287952986630526, Y1_loss = 0.1514708250761032, Y1_mse = 0.3891231417655945, Y2_loss = 0.48289141058921814, Y2_mse = 0.6909258365631104

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
